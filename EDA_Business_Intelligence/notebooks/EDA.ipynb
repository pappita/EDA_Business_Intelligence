# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/sales_data.csv")
df.head()
# Out:
#    order_id  customer_id product_name     category  revenue  marketing_spend  \
# 0         1          101        Phone  Electronics      500               50
# 1         2          102       Laptop  Electronics      900               80
# 2         3          103        Shoes      Fashion      120               20
# 3         4          104       Tshirt      Fashion       60               10
# 4         5          105        Watch  Accessories      200               25
#
#    order_date
# 0  2024-01-05
# 1  2024-01-10
# 2  2024-02-15
# 3  2024-02-20
# 4  2024-03-01

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_id         10 non-null     int64
#  1   customer_id      10 non-null     int64
#  2   product_name     10 non-null     object
#  3   category         10 non-null     object
#  4   revenue          10 non-null     int64
#  5   marketing_spend  10 non-null     int64
#  6   order_date       10 non-null     object
# dtypes: int64(4), object(3)
# memory usage: 692.0+ bytes
#        order_id  customer_id     revenue  marketing_spend
# count  10.00000    10.000000   10.000000        10.000000
# mean    5.50000   104.600000  303.000000        35.500000
# std     3.02765     2.875181  258.244071        20.249829
# min     1.00000   101.000000   60.000000        10.000000
# 25%     3.25000   102.250000  135.000000        22.750000
# 50%     5.50000   104.500000  210.000000        29.000000
# 75%     7.75000   106.750000  437.500000        47.500000
# max    10.00000   109.000000  900.000000        80.000000

# %%
df['revenue'].hist()
plt.title("Revenue Distribution")
plt.show()

# %%
df['category'].value_counts().plot(kind='bar')
plt.title("Category Count")
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.scatter(df['marketing_spend'], df['revenue'])
plt.xlabel("Marketing Spend")
plt.ylabel("Revenue")
plt.title("Marketing vs Revenue")
plt.show()
